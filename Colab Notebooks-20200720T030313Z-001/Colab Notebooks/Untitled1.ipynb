# %%
# 82(49, 57) - array; dojang Unit36, 37 for array and 2-dim'al array
# 174, 246/247 - { return cellTopSideNormVecX_[i][j]; }
# 179/180 - { return cellTopSideNormVecX_[i][j]; }

# %%
#include <stdio.h>

# %%
Nx = 100 # divisions in x-direction
Np = 100 # divisions in p_direction

# %%
numCellX = Nx + 2
numCellP = Np + 2
#Pass Line 24~27
numGridPtX = numCellX + 1 #Number of grid points, x-direction (Including ghost cells?)
numGridPtP = numCellP + 1 #Number of grid points, p-direction (Including ghost cells?)

# %%
##Numerical Solutions for 2D Arrays
#double T_[numCellX][numCellP], q_[numCellX][numCellP];
#double u_[numCellX][numCellP], w_[numCellX][numCellP], phix_[numCellX][numCellP]

# %%
##Grid Poinets

# %%
##Dx;  // x step size, defined in calcGridPts()
##cellLeftDp_[numGridPtX];  // Stores the Dp values on cell left sides, defined in calcGridPts()

# %%
#// The following two arrays store the grid point coordinates. meshGridX stores x coord on cell
#// left sides, and meshGridP stores p coord on cell bottom-left sides
#double meshGridX_[numGridPtX];  // Stores x_{i-1/2,j}, independent of j
#double meshGridP_[numGridPtX][numGridPtP];  // Stores p_{i-1/2,j-1/2}
#LIne53 Void??

# %%
#for (int i = 0; i < numGridPtX; ++i) {
#		double x = x0 + (i - 1) * Dx;
#		meshGridX_[i] = x;
#		double Dp = ((*pB_fptr)(x) - pA) / Np;
#		cellLeftDp_[i] = Dp;
#		for (int j = 0; j < numGridPtP; ++j) {
#			meshGridP_[i][j] = pA + (j - 1) * Dp;
#
#		}
#	}
import numpy as np
xf = 1
x0 = 0
pA = 200
Dx = (xf - x0) / Nx
meshGridX_ = np.zeros((numGridPtX, 1)) #make list
cellLeftDp_ = np.zeros((numGridPtX, 1))
meshGridP_ = np.zeros((numGridPtX, numGridPtP))
i = 0
j = 0
for i in range(0, numGridPtX): #From 0 to Const_numGridPtX - 1
    x = x0 + (i - 1) * Dx
    meshGridX_[i] = x 
    Dp = (10000 - pA) / Np
    #*pB_fptr == pB_fcn_MDL0 (==10000 with intentional setting))??
    cellLeftDp_[i] = Dp 
    i == i + 1
    for j in range (0, numGridPtP):
        meshGridP_[i][j] = pA + (j - 1) * Dp
        j == j + 1

# %%
# double getCellRightSideLen(int i, int j) { return cellLeftDp_[i + 1]; }
# double getCellRightSideLen(int i) { return cellLeftDp_[i + 1]; }
i = 0
j = 0
for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellRightSideLen = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1)
        getCellRightSideLen[i][j] = cellLeftDp_[i + 1][0] # cellLeftDp_ = np.zeros((numGridPtX, 1))

i = 0
j = 0
for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellLeftSideLen = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1)
        getCellLeftSideLen[i][j] = cellLeftDp_[i][0] # cellLeftDp_ = np.zeros((numGridPtX, 1))

# %%
#double getCellBottLeftP(int i, int j) { return meshGridP_[i][j]; }
#double getCellBottRightP(int i, int j) { return meshGridP_[i + 1][j]; }
i = 0
j = 0
for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellBottRightP = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1)
        getCellBottRightP[i][j] = meshGridP_[i + 1][0] # meshGridP_ = np.zeros((numGridPtX, 1))

i = 0
j = 0
for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellBottLeftP = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1)
        getCellBottLeftP[i][j] = meshGridP_[i][0] # meshGridP_ = np.zeros((numGridPtX, 1))

# %%
A = np.zeros((1,1))
A
# Out:
# array([[0.]])

# %%
A=np.zeros((2,2))
A[0][1] = 1
A
# Out:
# array([[0., 1.],
#        [0., 0.]])

# %%
a == range(0, 2) #from 0 to 1
a
# Out:
# range(0, 2)

# %%
#// Calculate all cell sides length: calculate bottom side length of cell (i, j)
#void calcCellSideLen() {
#	for (int i = 0; i < numCellX; ++i)
#		for (int j = 0; j < numCellP; ++j) {
#			double diffP = getCellBottRightP(i, j) - getCellBottLeftP(i, j);
#			cellBottSideLen_[i][j] = sqrt(Dx * Dx + diffP * diffP);
#		}
#}

#cellLeftDp = np.zeros(numGridPtX, 1)

i = 0
j = 0
for i in range(0, numCellX + 1):
    i = i + 1
    for j in range(0, numCellP + 1):
        diffP = getCellBottRightP[i][j] - getCellBottLeftP[i][j]
        cellBottSideLen_[i][j] = sqrt(Dx * Dx + diffP * diffP)

# %%
#double getCellBottSideLen(int i, int j) { return cellBottSideLen_[i][j]; }
#double getCellTopSideLen(int i, int j) { return cellBottSideLen_[i][j + 1]; }
for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellTopSideLen = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1)
        getCellTopSideLen[i][j] = cellBottSideLen_[i][j + 1] # cellBottSideLen_ = np.zeros((numGridPtX, 1))


for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellBottSideLen = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1)
        getCellBottSideLen[i][j] = cellBottSideLen_[i][j] # cellBottSideLen_ = np.zeros((numGridPtX, 1))

# %%
#/*
# * Getters for normal vectors on cell TOP sides. Getters for the bottom sides are not defined
# * on purpose, to be consistent with the notations in the article
# */

#double getCellTopSideNormVecX(int i, int j) { return cellTopSideNormVecX_[i][j]; }
#double getCellTopSideNormVecP(int i, int j) { return cellTopSideNormVecP_[i][j]; }

cellTopSideNormVecX_ = np.zeros(numCellX, numCellP)
cellTopSideNormVecP_ = np.zeros(numCellX, numCellP)



for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellTopSideNormVecX = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1) FIX - (numGridPtX +1, numGridPtP + 1)
        getCellTopSideNormVecX[i][j] = cellTopSideNormVecX_[i][j] # cellTopSideNormVecX_ = np.zeros((numGridPtX, 1))


for i in range(0, numGridPtX - 1) : # i is from 0 to numGridPtX - 2 -- Considier index again????
    for j in range(0, numGridPtP + 1): # j is from 0 to numGridPtP
        getCellTopSideNormVecP = np.zeros((numGridPtX +1, numGridPtP + 1)) # zero matrix for (numGridPtX +1) by (numGridPtP +1)
        getCellTopSideNormVecP[i][j] = cellTopSideNormVecP_[i][j] # cellTopSideNormVecP_ = np.zeros((numGridPtX, 1))
